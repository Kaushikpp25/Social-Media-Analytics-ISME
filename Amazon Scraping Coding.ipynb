# %%
import requests
from bs4 import BeautifulSoup

# %%
header={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36'}

# %%
cookie={'csm-hit':'tb:5HMYKSHHYYG66A1C0GK9+s-YX75TBEM91P7K20GH93T|1575368594749&t:1575368594750&adb:adblk_no','csm-sid':'627-4442442-8853062','i18n-prefs':'USD','session-id':'146-0073028-9825537','session-id-time':'2082787201l','session-token':'','skin':'noskin','sp-cdn':'"L5Z9:IN"','ubid-main':'135-9413133-8127618','x-amz-captcha-1':'1575373170058297','x-amz-captcha-2':'QAKF4FWUfi2SO0qu6wauPw==','x-wl-uid':'1Krjm3lYGTQ+XyYUFyi3FPSSF8R1MSiF96YYoqYGCubmk3MidPJ0oq1N/pKajNAV/slJVu2u7Pxk='}

# %%
def getAmazonSearch(search_query):
    url="https://www.amazon.in/s?k="+search_query
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"
    #print(page.content)

# %%
product=[]
response=getAmazonSearch('puma+shoes+for+men')
#beautifulsoup is a package
soup=BeautifulSoup(response.content)
for i in soup.findAll("span",{'class':'a-size-medium a-color-base a-text-normal'}):
    product.append(i.text)
# Out:
# https://www.amazon.in/s?k=puma+shoes+for+men

# %%
def Search(search_query):
    url="https://www.amazon.in/dp/"+search_query
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
def Search_1(search_query):
    url="https://www.amazon.in"+search_query
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
product=[]
response=getAmazonSearch('puma+shoes+for+men')
#beautifulsoup is a package
soup=BeautifulSoup(response.content)
for i in soup.findAll("span",{'class':'a-size-base-plus a-color-base a-text-normal'}):
    product.append(i.text)
# Out:
# https://www.amazon.in/s?k=puma+shoes+for+men

# %%
product
# Out:
# ["Puma Men's Willow IDP Sneakers",
#  "Adidas Men's Glick M Running Shoes",
#  "Nike Men's Downshifter 9 Running Shoes",
#  "Puma Men's Rapid Runner IDP Sneakers",
#  "Reebok Men's Tread Leap Running Shoes",
#  "Men's Willow IDP Sneakers",
#  "Men's Alacrity Idp Running Shoes",
#  "Men's Neutron IDP Running Shoes",
#  "Men's Flipster IDP Sneakers",
#  "Men's Lazer Evo Idp Running Shoes",
#  "Men's Hurdler Idp Running Shoes",
#  "Men's Morgan Sl Idp Running Shoes",
#  "Men's Shoe",
#  "Men's Corona Idp Sneakers",
#  "Men's Voyager IDP Running Shoes",
#  "Men's Rapid Runner Idp Running Shoes",
#  "Men's Sear Idp Running Shoes",
#  "Men's Shoes",
#  "Men's Funk Slip on IDP Sneakers",
#  "Men's Flipster Idp Running Shoes",
#  "The Admiral's Daughter (Men of Action)",
#  "Men's Convex Pro IDP Running Shoes",
#  "by Red Chief Green Men's Hiking Sport Shoes (H20001 788)",
#  'by Red Chief Sports Running Shoes for Men V1003',
# ...

# %%
data_asin=[]
response=getAmazonSearch('puma+shoes+for+men')
#beautifulsoup is a package
soup=BeautifulSoup(response.content)
for i in soup.findAll("div",{'class':"sg-col-4-of-24 sg-col-4-of-12 sg-col-4-of-36 s-result-item sg-col-4-of-28 sg-col-4-of-16 sg-col sg-col-4-of-20 sg-col-4-of-32"}):
    data_asin.append(i['data-asin'])
# Out:
# https://www.amazon.in/s?k=puma+shoes+for+men

# %%
data_asin
# Out:
# ['B07V2BSMDW',
#  'B07N7MMZTT',
#  'B07T3DDX1D',
#  'B07NQLMY8Q',
#  'B07N7M4FV2',
#  'B07V3N8HVS',
#  'B07V8N55X2',
#  'B07NQLK1FN',
#  'B07NHQRGV2',
#  'B07FP9CM6F',
#  'B07NQL91DL',
#  'B07QNJNGLV',
#  'B07NQJW59N',
#  'B07HWTC7S8',
#  'B07NQJSSLW',
#  'B07NQJS2CN',
#  'B0054KPRRM',
#  'B07NQL1Z5S',
#  'B07HX5KTCC',
#  'B07V7RNMYM',
#  'B07NHQBBJN',
#  'B07V5KJQ72',
#  'B07J565JJS',
#  'B07QLL3BF8',
#  'B07QV173RS',
#  'B07J4RSXPT',
#  'B07NQJW59M',
#  'B07NHQZXG6',
#  'B07NQJ5512',
#  'B07NQKQWJS',
#  'B07NQKTDN4',
#  'B07N7PC9FM',
#  'B07NHSRRKH',
#  'B07V4GW8KZ',
#  'B07NQK8T3Y',
#  'B07FNVK1QB',
#  'B07N7M4GLG',
#  'B07FQGTB9R',
#  'B07N7N73BR',
#  'B07FNPWMWJ',
#  'B07J56CMDV',
#  'B07T2D7RWL',
#  'B07NHR4W5N',
#  'B07N7Q8M3S',
#  'B07FP9GB5Q',
#  'B07V4GWDK1',
#  'B07FNPYSNX',
#  'B07FNWT1Z9']

# %%
len(data_asin)
# Out:
# 48

# %%
link=[]
for i in range(len(data_asin)-1):
    response=Search(data_asin[i+1])
#beautifulsoup is a package
    soup=BeautifulSoup(response.content)
    for i in soup.findAll("a",{'data-hook':"see-all-reviews-link-foot"}):
        link.append(i['href'])
# Out:
# https://www.amazon.in/dp/B07N7MMZTT
# https://www.amazon.in/dp/B07T3DDX1D
# https://www.amazon.in/dp/B07NQLMY8Q
# https://www.amazon.in/dp/B07N7M4FV2
# https://www.amazon.in/dp/B07V3N8HVS
# https://www.amazon.in/dp/B07V8N55X2
# https://www.amazon.in/dp/B07NQLK1FN
# https://www.amazon.in/dp/B07NHQRGV2
# https://www.amazon.in/dp/B07FP9CM6F
# https://www.amazon.in/dp/B07NQL91DL
# https://www.amazon.in/dp/B07QNJNGLV
# https://www.amazon.in/dp/B07NQJW59N
# https://www.amazon.in/dp/B07HWTC7S8
# https://www.amazon.in/dp/B07NQJSSLW
# https://www.amazon.in/dp/B07NQJS2CN
# https://www.amazon.in/dp/B0054KPRRM
# https://www.amazon.in/dp/B07NQL1Z5S
# https://www.amazon.in/dp/B07HX5KTCC
# https://www.amazon.in/dp/B07V7RNMYM
# https://www.amazon.in/dp/B07NHQBBJN
# https://www.amazon.in/dp/B07V5KJQ72
# https://www.amazon.in/dp/B07J565JJS
# https://www.amazon.in/dp/B07QLL3BF8
# https://www.amazon.in/dp/B07QV173RS
# https://www.amazon.in/dp/B07J4RSXPT
# https://www.amazon.in/dp/B07NQJW59M
# ...

# %%
len(link)
# Out:
# 46

# %%
rev=[]
for j in range(len(link)):
    for k in range(100):
        response=Search_1(link[j]+'&pageNumber='+str(k))
#beautifulsoup is a package
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("span",{'data-hook':"review-body"}):
            rev.append(i.text)
# Out:
# https://www.amazon.in/Puma-Mens-Willow-IDP-Sneakers/product-reviews/B07NJK31ML/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Puma-Mens-Willow-IDP-Sneakers/product-reviews/B07NJK31ML/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Puma-Mens-Willow-IDP-Sneakers/product-reviews/B07NJK31ML/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Puma-Mens-Willow-IDP-Sneakers/product-reviews/B07NJK31ML/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Puma-Mens-Willow-IDP-Sneakers/product-reviews/B07NJK31ML/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Puma-Mens-Willow-IDP-Sneakers/product-reviews/B07NJK31ML/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# ...

# %%
len(rev)
# Out:
# 3101

# %%
rev[:70]
# Out:
# ['\nThank you amazon for sending its before pujo and the product is amazing\n',
#  '\nGood quality but little tight near the laces\n',
#  '\nColour was different. In picture it is shown black,in real it was blue. Shoe laces are too small. Not as expected.\n',
#  '\nLooking good  & quality also better\n',
#  '\nvery bad product\n',
#  '\nSuper\n',
#  '\nValue of money\n',
#  '\nAmazing product...looks smart n stylish....worth the money!!\n',
#  '\nDefective\n',
#  '\nQuality not good as expected\n',
#  '\nThank you amazon for sending its before pujo and the product is amazing\n',
#  '\nGood quality but little tight near the laces\n',
#  '\nColour was different. In picture it is shown black,in real it was blue. Shoe laces are too small. Not as expected.\n',
#  '\nLooking good  & quality also better\n',
#  '\nvery bad product\n',
#  '\nSuper\n',
#  '\nValue of money\n',
#  '\nAmazing product...looks smart n stylish....worth the money!!\n',
#  '\nDefective\n',
# ...

# %%
import pandas as pd

# %%
del data_asin[:]

# %%
response=getAmazonSearch('puma+shoes+for+men&page=2')
soup=BeautifulSoup(response.content)
for i in soup.findAll("div",{'class':"sg-col-4-of-24 sg-col-4-of-12 sg-col-4-of-36 s-result-item sg-col-4-of-28 sg-col-4-of-16 sg-col sg-col-4-of-20 sg-col-4-of-32"}):
    data_asin.append(i['data-asin'])
# Out:
# https://www.amazon.in/s?k=puma+shoes+for+men&page=2

# %%
len(data_asin)
# Out:
# 48

# %%
del link[:]

# %%
len(link)
# Out:
# 0

# %%
for i in range(len(data_asin)-1):
    response=Search(data_asin[i+1])
    soup=BeautifulSoup(response.content)
    for i in soup.findAll("a",{'data-hook':"see-all-reviews-link-foot"}):
        link.append(i['href'])
# Out:
# https://www.amazon.in/dp/B07V6N6TTH
# https://www.amazon.in/dp/B07F3VWB8F
# https://www.amazon.in/dp/B07FQGN4RP
# https://www.amazon.in/dp/B07NQHV45J
# https://www.amazon.in/dp/B07NHQ9D67
# https://www.amazon.in/dp/B07V3GNMNN
# https://www.amazon.in/dp/B07NQJSSLW
# https://www.amazon.in/dp/B07R9RNKNT
# https://www.amazon.in/dp/B07V7R1JY8
# https://www.amazon.in/dp/B07FNPYSNX
# https://www.amazon.in/dp/B07V4GW9YB
# https://www.amazon.in/dp/B07NHSTXK4
# https://www.amazon.in/dp/B07NHPTW8R
# https://www.amazon.in/dp/B07NQL1Z5S
# https://www.amazon.in/dp/B07NQKTDN4
# https://www.amazon.in/dp/B07V8N256S
# https://www.amazon.in/dp/B07NQJZYTY
# https://www.amazon.in/dp/B07V5KJKMN
# https://www.amazon.in/dp/B078ZVRBX4
# https://www.amazon.in/dp/B07N7MN9R8
# https://www.amazon.in/dp/B07N7MPVST
# https://www.amazon.in/dp/B01EA1PIW4
# https://www.amazon.in/dp/B07FNWT1Z9
# https://www.amazon.in/dp/B07QV173RS
# https://www.amazon.in/dp/B07V7RFCNS
# https://www.amazon.in/dp/B07NQK2R8J
# ...

# %%
len(link)
# Out:
# 46

# %%
for j in range(len(link)):
    for k in range(100):
        response=Search_1(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("span",{'data-hook':"review-body"}):
            rev.append(i.text)
# Out:
# https://www.amazon.in/Puma-Men-Alacrity-IDP/product-reviews/B07VT3NQFN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Puma-Men-Alacrity-IDP/product-reviews/B07VT3NQFN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Puma-Men-Alacrity-IDP/product-reviews/B07VT3NQFN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Puma-Men-Alacrity-IDP/product-reviews/B07VT3NQFN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Puma-Men-Alacrity-IDP/product-reviews/B07VT3NQFN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Puma-Men-Alacrity-IDP/product-reviews/B07VT3NQFN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# ...

# %%
len(rev)
# Out:
# 4937

# %%
reviews={'rev':rev}

# %%
review_data=pd.DataFrame.from_dict(reviews)

# %%
review_data.sample(5)
# Out:
#                                                     rev
# 3570             \nGood fitting...true value of money\n
# 4928                                   \nBest product\n
# 4909  \nFoot breadth should mention in Size table…on...
# 620                   \nSuperb quality got it for 199\n
# 1694  \nAwesome shoes. Just go for it. Got in Amazon...

# %%
review_data.shape
# Out:
# (4937, 1)

# %%
review_data.to_csv('Amazon Scraping Reviews.csv',index=False)
